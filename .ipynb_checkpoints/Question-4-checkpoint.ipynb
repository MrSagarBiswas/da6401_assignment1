# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from keras.datasets import fashion_mnist

# %%
from Model import NeuralNet, InputLayer, DenseLayer, Sigmoid, Softmax, OneHotEncoder

# %%
print("Loading Fashion MNIST data...")
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
train_images, val_images, train_labels, val_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=2
)
print("Done!")
# Out:
# Loading Fashion MNIST data...
# Done!

# %%
# Flatten images and transpose: each column represents one flattened image
train_features = train_images.reshape(train_images.shape[0], -1).T
val_features = val_images.reshape(val_images.shape[0], -1).T
test_features = test_images.reshape(test_images.shape[0], -1).T

# %%
encoder = OneHotEncoder()
encoder.fit(train_labels, 10)
train_targets = encoder.transform(train_labels)
val_targets = encoder.transform(val_labels)
test_targets = encoder.transform(test_labels)

# %%
train_features = train_features[:, :2000]
val_features = val_features[:, :500]
test_features = val_features[:, :250]
train_targets = train_targets[:, :2000]
val_targets = val_targets[:, :500]
test_targets = val_targets[:, :250]

# %%
network_layers = [
    InputLayer(data=train_features),
    DenseLayer(units=64, activation=Sigmoid(), name="HiddenLayer1"),
    DenseLayer(units=10, activation=Softmax(), name="OutputLayer")
]

# %%
model = NeuralNet(
    layers=network_layers,
    batch_size=2000,
    optimizer_name="Basic",
    init_method="RandomNormal",
    epochs=100,
    targets=train_targets,
    loss_type="CrossEntropy",
    X_val=val_features,
    targets_val=val_targets,
    use_wandb=False
)

# %%
model.forward_pass()
initial_output = model.layers[-1].output

# %%
history = model.backward_pass()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [00:04<00:00, 22.18it/s]

# %%
val_acc, val_loss, _ = model.evaluate(val_features, val_targets)
test_acc, test_loss, _ = model.evaluate(test_features, test_targets)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 val_acc, val_loss, _ = model.evaluate(val_features, val_targets)
#       2 test_acc, test_loss, _ = model.evaluate(test_features, test_targets)
#
# File ~\Desktop\da6401_assignment1\Model.py:161, in NeuralNet.evaluate(self, X_test, targets_test)
#     159 self.layers[0].test_data = X_test
#     160 for idx in range(1, len(self.layers)):
# --> 161     self.layers[idx].test_linear = np.dot(self.layers[idx-1].test_data.T, self.layers[idx].weights).T - self.layers[idx].biases
#     162     self.layers[idx].test_output = self.layers[idx].activation.compute(self.layers[idx].test_linear)
#     163 if self.loss_type == "CrossEntropy":
#
# AttributeError: 'DenseLayer' object has no attribute 'test_data'

# %%
print("Training Results:")
# Calculate initial and final accuracy on the training subset
initial_accuracy = np.mean(np.argmax(initial_output, axis=0) == train_labels_subset)
final_accuracy = np.mean(np.argmax(model.layers[-1].output, axis=0) == train_labels_subset)
print("Untrained network accuracy on training subset:", initial_accuracy)
print("Trained network accuracy on training subset:", final_accuracy)

print("Validation Results:")
print("Validation accuracy:", val_acc / val_targets.shape[1])
print("Validation loss:", val_loss)

print("Test Results:")
print("Test accuracy:", test_acc / test_targets.shape[1])
print("Test loss:", test_loss)
